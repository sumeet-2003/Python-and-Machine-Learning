# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img=cv2.imread("D://TS_IMG/1690523263290.png")
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
import os
def main():
	i = 0
	path=""		#provide full path like {"D://dataset/healthy"}
	for filename in os.listdir(path):
		my_dest ="Hispa_" + str(i) + ".jpg"	#change the title according to the dataset
		my_source =path + filename
		my_dest =path + my_dest
		os.rename(my_source, my_dest)		# rename() function will rename all the files
		i += 1
# Driver Code
if __name__ == '__main__':
	main()

# %%
# machine learning code for age predecction using open cv.
